# %%
import os.path
import sys
from bids.grabbids import BIDSLayout
import ciftify.utils
from ciftify.utils import run, get_number_cpus, section_header
import logging
from docopt import docopt
import pandas as pd
import ciftify.bidsapp.run as run_script

# %%
def freesurfer_is_complete(settings, participant_label):
    '''returns bool of wether or not the wmparc.mgz was found'''
    fs_sub_dir = os.path.join(settings.fs_dir,
                                 'sub-{}'.format(participant_label))
    finished_fs = os.path.isfile(os.path.join(fs_sub_dir, 'mri', 'wmparc.mgz'))
    return finished_fs

def ciftify_log_endswith_done(ciftify_log):
    '''return true with the ciftify log file exists and ends with the word Done'''
    if not os.path.isfile(ciftify_log):
        return False
    with open(ciftify_log, 'r') as f:
        lines = f.read().splitlines()
        last_line = lines[-3]
        is_done = True if 'Done' in last_line else False
    return is_done

def has_ciftify_recon_all_run(settings, participant_label):
    '''determine if ciftify_recon_all has already completed'''
    ciftify_log = os.path.join(settings.ciftify_work_dir,
                        'sub-{}'.format(participant_label),
                        'cifti_recon_all.log')
    return ciftify_log_endswith_done(ciftify_log)

def has_ciftify_fmri_run(subject, fmriname, settings):
    '''determine if ciftify_recon_all has already completed'''
    ciftify_log = os.path.join(settings.ciftify_work_dir,
                        'sub-{}'.format(subject),
                        'MNINonLinear', 'Results', fmriname,
                        'ciftify_subject_fmri.log')
    return ciftify_log_endswith_done(ciftify_log)

# %%
def build_dataframe_of_completed_runs(settings):
    '''checks all runs for completeness and builds a dataframe'''
    df = settings.bids_layout.as_data_frame()

    for subject in df.subject.unique():
        df.loc[df.loc[:, 'subject']== subject, 'freesurfer_done'] = freesurfer_is_complete(settings, subject)
        df.loc[df.loc[:, 'subject']== subject, 'ciftify_anat_done'] = has_ciftify_recon_all_run(settings, subject)

    for idx in df.index:
        if df.loc[idx, 'type'] == "bold":
            if 'session' in df.columns:
                bold_input_list = settings.bids_layout.get(subject = df.loc[idx, 'subject'],
                                                           type="bold",
                                                           session = df.loc[idx, 'session'],
                                                           task = df.loc[idx, 'task'],
                                                           extensions=["nii.gz", "nii"])
            else: 
                bold_input_list = settings.bids_layout.get(subject = df.loc[idx, 'subject'],
                                                           type="bold",
                                                           task = df.loc[idx, 'task'],
                                                           extensions=["nii.gz", "nii"])
            try:
                bold_input = bold_input_list[0]
                bold_preproc, fmriname = run_script.find_bold_preproc(bold_input, settings)
                df.loc[idx, 'fmriprep_done'] = os.path.isfile(bold_preproc)
                df.loc[idx, 'ciftify_fmri_done'] = has_ciftify_fmri_run(df.loc[idx, 'subject'], fmriname, settings)
            except:
                print('row {} is weird'.format(idx))
    return df

# %%
def print_ciftify_anat_deleting_code(df, settings):
    subs_to_delete_ciftify_anat = df.loc[df.loc[:, 'ciftify_anat_done']==False, 'subject']
    for sub in subs_to_delete_ciftify_anat:
        print('rm -r {}/sub-{}'.format(settings.ciftify_work_dir, sub))
# Out:
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-9061
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-8873
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-11316
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-9612
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-7927
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-8350
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-7960
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-9390
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-8619
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-8586
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-6891
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-9141
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-9125
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-8946
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-7937
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-8889
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-9194
# rm -r /scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/ciftify/sub-8949

# %%
def print_ciftify_fmri_deleting_code(df, settings):
    '''prints code to remove half done ciftify_subject_fmri runs'''
    df_step1 = df_rest.loc[df.loc[:, 'ciftify_anat_done']==True, :]
    df_step2 = df_step1.loc[df_step1.loc[:, 'ciftify_fmri_done']==False, :]

    for idx in df_step2.index:
        if session
        bold_input_list = settings.bids_layout.get(subject = df_step2.loc[idx, 'subject'],
                                                   type="bold",
                                                   session = df_step2.loc[idx, 'session'],
                                                   task = df_step2.loc[idx, 'task'],
                                                   extensions=["nii.gz", "nii"])

        bold_input = bold_input_list[0]
        bold_preproc, fmriname = run_script.find_bold_preproc(bold_input, settings)
        print('rm -r {}/sub-{}/MNINonLinear/Results/{}'.format(settings.ciftify_work_dir, bold_input.subject, fmriname))

# %%
arguments_zhh  = docopt(run_script.__doc__, ['/scratch/dmiranda/BIDS_ZHH', '/scratch/edickie/saba_PINT/ciftify_fmriprep/ZHH/out/', 'participant', '--task=rest'])

# %%
settings_zhh = run_script.Settings(arguments_zhh)
# Out:
# cmd: bids-validator /scratch/dmiranda/BIDS_ZHH
#  Failed with returncode 127
# /bin/sh: 1: bids-validator: not found

# %%
df_zhh = build_dataframe_of_completed_runs(settings_zhh)
df_rest_zhh = df_zhh.loc[df_zhh.loc[:, 'task']=="rest", :]
# Out:
# row 92 is weird

# %%
df_rest_zhh
# Out:
#                                                   path modality session  \
# 0    /scratch/dmiranda/BIDS_ZHH/sub-10944/ses-01/fu...     func      01
# 2    /scratch/dmiranda/BIDS_ZHH/sub-9104/ses-01/fun...     func      01
# 4    /scratch/dmiranda/BIDS_ZHH/sub-7735/ses-01/fun...     func      01
# 6    /scratch/dmiranda/BIDS_ZHH/sub-8523/ses-01/fun...     func      01
# 8    /scratch/dmiranda/BIDS_ZHH/sub-3123/ses-01/fun...     func      01
# 10   /scratch/dmiranda/BIDS_ZHH/sub-5692/ses-02/fun...     func      02
# 12   /scratch/dmiranda/BIDS_ZHH/sub-9878/ses-01/fun...     func      01
# 14   /scratch/dmiranda/BIDS_ZHH/sub-9799/ses-01/fun...     func      01
# 16   /scratch/dmiranda/BIDS_ZHH/sub-9061/ses-01/fun...     func      01
# 18   /scratch/dmiranda/BIDS_ZHH/sub-11323/ses-02/fu...     func      02
# 20   /scratch/dmiranda/BIDS_ZHH/sub-11323/ses-01/fu...     func      01
# 22   /scratch/dmiranda/BIDS_ZHH/sub-9045/ses-01/fun...     func      01
# 24   /scratch/dmiranda/BIDS_ZHH/sub-10185/ses-03/fu...     func      03
# 26   /scratch/dmiranda/BIDS_ZHH/sub-5216/ses-03/fun...     func      03
# 28   /scratch/dmiranda/BIDS_ZHH/sub-9617/ses-01/fun...     func      01
# 30   /scratch/dmiranda/BIDS_ZHH/sub-9330/ses-02/fun...     func      02
# 32   /scratch/dmiranda/BIDS_ZHH/sub-10245/ses-03/fu...     func      03
# 34   /scratch/dmiranda/BIDS_ZHH/sub-8873/ses-01/fun...     func      01
# 36   /scratch/dmiranda/BIDS_ZHH/sub-11315/ses-02/fu...     func      02
# 38   /scratch/dmiranda/BIDS_ZHH/sub-7749/ses-05/fun...     func      05
# 40   /scratch/dmiranda/BIDS_ZHH/sub-8984/ses-04/fun...     func      04
# 42   /scratch/dmiranda/BIDS_ZHH/sub-8984/ses-02/fun...     func      02
# 44   /scratch/dmiranda/BIDS_ZHH/sub-8984/ses-03/fun...     func      03
# 46   /scratch/dmiranda/BIDS_ZHH/sub-8984/ses-01/fun...     func      01
# 48   /scratch/dmiranda/BIDS_ZHH/sub-11316/ses-01/fu...     func      01
# 50   /scratch/dmiranda/BIDS_ZHH/sub-10511/ses-01/fu...     func      01
# 52   /scratch/dmiranda/BIDS_ZHH/sub-9737/ses-01/fun...     func      01
# 54   /scratch/dmiranda/BIDS_ZHH/sub-9573/ses-01/fun...     func      01
# 56   /scratch/dmiranda/BIDS_ZHH/sub-10608/ses-03/fu...     func      03
# 58   /scratch/dmiranda/BIDS_ZHH/sub-9612/ses-02/fun...     func      02
# ..                                                 ...      ...     ...
# 546  /scratch/dmiranda/BIDS_ZHH/sub-11305/ses-02/fu...     func      02
# 548  /scratch/dmiranda/BIDS_ZHH/sub-11305/ses-01/fu...     func      01
# 550  /scratch/dmiranda/BIDS_ZHH/sub-9194/ses-01/fun...     func      01
# 552  /scratch/dmiranda/BIDS_ZHH/sub-7661/ses-01/fun...     func      01
# 554  /scratch/dmiranda/BIDS_ZHH/sub-8500/ses-01/fun...     func      01
# 556  /scratch/dmiranda/BIDS_ZHH/sub-9577/ses-01/fun...     func      01
# 558  /scratch/dmiranda/BIDS_ZHH/sub-8018/ses-01/fun...     func      01
# 560  /scratch/dmiranda/BIDS_ZHH/sub-4609/ses-01/fun...     func      01
# 562  /scratch/dmiranda/BIDS_ZHH/sub-10818/ses-01/fu...     func      01
# 564  /scratch/dmiranda/BIDS_ZHH/sub-9623/ses-01/fun...     func      01
# 566  /scratch/dmiranda/BIDS_ZHH/sub-9284/ses-01/fun...     func      01
# 568  /scratch/dmiranda/BIDS_ZHH/sub-9404/ses-01/fun...     func      01
# 570  /scratch/dmiranda/BIDS_ZHH/sub-11399/ses-01/fu...     func      01
# 572  /scratch/dmiranda/BIDS_ZHH/sub-8887/ses-01/fun...     func      01
# 574  /scratch/dmiranda/BIDS_ZHH/sub-8949/ses-01/fun...     func      01
# 576  /scratch/dmiranda/BIDS_ZHH/sub-9287/ses-01/fun...     func      01
# 578  /scratch/dmiranda/BIDS_ZHH/sub-7576/ses-01/fun...     func      01
# 580  /scratch/dmiranda/BIDS_ZHH/sub-7726/ses-01/fun...     func      01
# 582  /scratch/dmiranda/BIDS_ZHH/sub-9714/ses-01/fun...     func      01
# 584  /scratch/dmiranda/BIDS_ZHH/sub-10681/ses-01/fu...     func      01
# 586  /scratch/dmiranda/BIDS_ZHH/sub-10294/ses-08/fu...     func      08
# 588  /scratch/dmiranda/BIDS_ZHH/sub-7488/ses-01/fun...     func      01
# 590  /scratch/dmiranda/BIDS_ZHH/sub-8842/ses-04/fun...     func      04
# 592  /scratch/dmiranda/BIDS_ZHH/sub-10683/ses-02/fu...     func      02
# 594  /scratch/dmiranda/BIDS_ZHH/sub-10683/ses-01/fu...     func      01
# 596  /scratch/dmiranda/BIDS_ZHH/sub-10662/ses-01/fu...     func      01
# 598  /scratch/dmiranda/BIDS_ZHH/sub-9095/ses-03/fun...     func      03
# 600  /scratch/dmiranda/BIDS_ZHH/sub-9568/ses-01/fun...     func      01
# 602  /scratch/dmiranda/BIDS_ZHH/sub-7252/ses-01/fun...     func      01
# 604  /scratch/dmiranda/BIDS_ZHH/sub-10854/ses-01/fu...     func      01
#
#     subject  task  type freesurfer_done ciftify_anat_done fmriprep_done  \
# 0     10944  rest  bold            True              True          True
# 2      9104  rest  bold            True              True          True
# 4      7735  rest  bold            True              True          True
# 6      8523  rest  bold            True              True          True
# 8      3123  rest  bold            True              True          True
# 10     5692  rest  bold            True              True          True
# 12     9878  rest  bold            True              True          True
# 14     9799  rest  bold            True              True          True
# 16     9061  rest  bold            True              True          True
# 18    11323  rest  bold            True              True          True
# 20    11323  rest  bold            True              True          True
# 22     9045  rest  bold            True              True          True
# 24    10185  rest  bold            True              True          True
# 26     5216  rest  bold            True              True          True
# 28     9617  rest  bold            True              True          True
# 30     9330  rest  bold            True              True          True
# 32    10245  rest  bold            True              True          True
# 34     8873  rest  bold            True              True          True
# 36    11315  rest  bold            True              True          True
# 38     7749  rest  bold            True              True          True
# 40     8984  rest  bold            True              True          True
# 42     8984  rest  bold            True              True          True
# 44     8984  rest  bold            True              True          True
# 46     8984  rest  bold            True              True          True
# 48    11316  rest  bold            True              True          True
# 50    10511  rest  bold            True              True          True
# 52     9737  rest  bold            True              True          True
# 54     9573  rest  bold            True              True          True
# 56    10608  rest  bold            True              True          True
# 58     9612  rest  bold           False             False         False
# ..      ...   ...   ...             ...               ...           ...
# 546   11305  rest  bold            True              True          True
# 548   11305  rest  bold            True              True          True
# 550    9194  rest  bold            True              True          True
# 552    7661  rest  bold            True              True          True
# 554    8500  rest  bold            True              True          True
# 556    9577  rest  bold            True              True          True
# 558    8018  rest  bold            True              True          True
# 560    4609  rest  bold            True              True          True
# 562   10818  rest  bold            True              True          True
# 564    9623  rest  bold            True              True          True
# 566    9284  rest  bold            True              True          True
# 568    9404  rest  bold            True              True          True
# 570   11399  rest  bold            True              True          True
# 572    8887  rest  bold            True              True          True
# 574    8949  rest  bold            True              True          True
# 576    9287  rest  bold            True              True          True
# 578    7576  rest  bold            True              True          True
# 580    7726  rest  bold            True              True          True
# 582    9714  rest  bold            True              True          True
# 584   10681  rest  bold            True              True          True
# 586   10294  rest  bold            True              True          True
# 588    7488  rest  bold            True              True          True
# 590    8842  rest  bold            True              True          True
# 592   10683  rest  bold            True              True          True
# 594   10683  rest  bold            True              True          True
# 596   10662  rest  bold            True              True          True
# 598    9095  rest  bold            True              True          True
# 600    9568  rest  bold            True              True          True
# 602    7252  rest  bold            True              True          True
# 604   10854  rest  bold            True              True          True
#
#     ciftify_fmri_done
# 0                True
# 2                True
# 4                True
# 6                True
# 8                True
# 10               True
# 12               True
# 14               True
# 16               True
# 18               True
# 20               True
# 22               True
# 24               True
# 26               True
# 28               True
# 30               True
# 32               True
# 34               True
# 36               True
# 38               True
# 40               True
# 42               True
# 44               True
# 46               True
# 48               True
# 50               True
# 52               True
# 54               True
# 56               True
# 58              False
# ..                ...
# 546              True
# 548              True
# 550              True
# 552              True
# 554              True
# 556              True
# 558              True
# 560              True
# 562              True
# 564              True
# 566              True
# 568              True
# 570              True
# 572              True
# 574              True
# 576              True
# 578              True
# 580              True
# 582              True
# 584              True
# 586              True
# 588              True
# 590              True
# 592              True
# 594              True
# 596              True
# 598              True
# 600              True
# 602              True
# 604              True
#
# [302 rows x 10 columns]

# %%
import datetime

today = datetime.datetime.today().strftime("%Y-%m-%d")

# %%
df_rest_zhh.to_csv(os.path.join(settings_zhh.ciftify_work_dir, 'ciftify_runs_complete_{}.csv'.format(today)))

# %%
subs_to_delete_ciftify_anat = df_rest.loc[df_rest.loc[:, 'ciftify_anat_done']==False, 'subject']

# %%
arguments_cobre  = docopt(run_script.__doc__, ['/scratch/edickie/saba_PINT/ciftify_fmriprep/COBRE/COBRE', '/scratch/edickie/saba_PINT/ciftify_fmriprep/COBRE/out/', 'participant', '--task=rest'])

# %%
settings_cobre = run_script.Settings(arguments_cobre)
df = build_dataframe_of_completed_runs(settings_cobre)
df_rest = df.loc[df.loc[:, 'task']=="rest", :]
# Out:
# cmd: bids-validator /scratch/edickie/saba_PINT/ciftify_fmriprep/COBRE/COBRE
#  Failed with returncode 127
# /bin/sh: 1: bids-validator: not found

# %%
df_rest
# Out:
#                                                    path  acq acquisition  \
# 0     /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 1     /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 23    /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 24    /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 49    /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 50    /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 73    /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 74    /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 99    /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 100   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 135   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 136   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 159   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 160   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 184   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 185   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 208   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 209   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 229   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 230   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 255   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 256   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 291   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 292   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 315   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 316   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 339   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 340   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 363   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 364   /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# ...                                                 ...  ...         ...
# 3215  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3216  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3251  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3252  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3274  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3275  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3310  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3311  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3348  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3349  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3385  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3386  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3409  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3410  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3435  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3436  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3459  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3460  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3484  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3485  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3520  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3521  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3544  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3545  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3570  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3571  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3598  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3599  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3638  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
# 3639  /scratch/edickie/saba_PINT/ciftify_fmriprep/CO...  NaN         NaN
#
#      modality  run scans   session    subject  task  type freesurfer_done  \
# 0        func  NaN   NaN  20110101  A00020416  rest  bold            True
# 1        func  NaN   NaN  20110101  A00020416  rest  bold            True
# 23       func  NaN   NaN  20100101  A00020416  rest  bold            True
# 24       func  NaN   NaN  20100101  A00020416  rest  bold            True
# 49       func  NaN   NaN  20100101  A00014522  rest  bold            True
# 50       func  NaN   NaN  20100101  A00014522  rest  bold            True
# 73       func  NaN   NaN  20110101  A00001243  rest  bold            True
# 74       func  NaN   NaN  20110101  A00001243  rest  bold            True
# 99       func  NaN   NaN  20100101  A00020787  rest  bold            True
# 100      func  NaN   NaN  20100101  A00020787  rest  bold            True
# 135      func  NaN   NaN  20100101  A00020968  rest  bold            True
# 136      func  NaN   NaN  20100101  A00020968  rest  bold            True
# 159      func  NaN   NaN  20110101  A00028052  rest  bold            True
# 160      func  NaN   NaN  20110101  A00028052  rest  bold            True
# 184      func  NaN   NaN  20110101  A00019888  rest  bold            True
# 185      func  NaN   NaN  20110101  A00019888  rest  bold            True
# 208      func  NaN   NaN  20110101  A00014175  rest  bold            True
# 209      func  NaN   NaN  20110101  A00014175  rest  bold            True
# 229      func  NaN   NaN  20100101  A00023590  rest  bold            True
# 230      func  NaN   NaN  20100101  A00023590  rest  bold            True
# 255      func  NaN   NaN  20100101  A00000838  rest  bold            True
# 256      func  NaN   NaN  20100101  A00000838  rest  bold            True
# 291      func  NaN   NaN  20110101  A00011725  rest  bold            True
# 292      func  NaN   NaN  20110101  A00011725  rest  bold            True
# 315      func  NaN   NaN  20100101  A00020895  rest  bold            True
# 316      func  NaN   NaN  20100101  A00020895  rest  bold            True
# 339      func  NaN   NaN  20090101  A00024546  rest  bold            True
# 340      func  NaN   NaN  20090101  A00024546  rest  bold            True
# 363      func  NaN   NaN  20110101  A00010150  rest  bold            True
# 364      func  NaN   NaN  20110101  A00010150  rest  bold            True
# ...       ...  ...   ...       ...        ...   ...   ...             ...
# 3215     func  NaN   NaN  20100101  A00004087  rest  bold            True
# 3216     func  NaN   NaN  20100101  A00004087  rest  bold            True
# 3251     func  NaN   NaN  20110101  A00000541  rest  bold            True
# 3252     func  NaN   NaN  20110101  A00000541  rest  bold            True
# 3274     func  NaN   NaN  20100101  A00000541  rest  bold            True
# 3275     func  NaN   NaN  20100101  A00000541  rest  bold            True
# 3310     func  NaN   NaN  20090101  A00023243  rest  bold            True
# 3311     func  NaN   NaN  20090101  A00023243  rest  bold            True
# 3348     func  NaN   NaN  20110101  A00027787  rest  bold            True
# 3349     func  NaN   NaN  20110101  A00027787  rest  bold            True
# 3385     func  NaN   NaN  20090101  A00016197  rest  bold            True
# 3386     func  NaN   NaN  20090101  A00016197  rest  bold            True
# 3409     func  NaN   NaN  20110101  A00000368  rest  bold            True
# 3410     func  NaN   NaN  20110101  A00000368  rest  bold            True
# 3435     func  NaN   NaN  20100101  A00014607  rest  bold            True
# 3436     func  NaN   NaN  20100101  A00014607  rest  bold            True
# 3459     func  NaN   NaN  20090101  A00022509  rest  bold            True
# 3460     func  NaN   NaN  20090101  A00022509  rest  bold            True
# 3484     func  NaN   NaN  20100101  A00001181  rest  bold            True
# 3485     func  NaN   NaN  20100101  A00001181  rest  bold            True
# 3520     func  NaN   NaN  20090101  A00024301  rest  bold            True
# 3521     func  NaN   NaN  20090101  A00024301  rest  bold            True
# 3544     func  NaN   NaN  20110101  A00018553  rest  bold            True
# 3545     func  NaN   NaN  20110101  A00018553  rest  bold            True
# 3570     func  NaN   NaN  20110101  A00027391  rest  bold            True
# 3571     func  NaN   NaN  20110101  A00027391  rest  bold            True
# 3598     func  NaN   NaN  20090101  A00024372  rest  bold            True
# 3599     func  NaN   NaN  20090101  A00024372  rest  bold            True
# 3638     func  NaN   NaN  20110101  A00007409  rest  bold            True
# 3639     func  NaN   NaN  20110101  A00007409  rest  bold            True
#
#      ciftify_anat_done fmriprep_done ciftify_fmri_done
# 0                 True          True              True
# 1                 True          True              True
# 23                True          True              True
# 24                True          True              True
# 49                True          True              True
# 50                True          True              True
# 73                True          True              True
# 74                True          True              True
# 99                True          True              True
# 100               True          True              True
# 135               True          True              True
# 136               True          True              True
# 159               True          True              True
# 160               True          True              True
# 184               True          True              True
# 185               True          True              True
# 208               True          True              True
# 209               True          True              True
# 229               True          True              True
# 230               True          True              True
# 255               True          True              True
# 256               True          True              True
# 291               True          True              True
# 292               True          True              True
# 315               True          True              True
# 316               True          True              True
# 339               True          True              True
# 340               True          True              True
# 363               True          True              True
# 364               True          True              True
# ...                ...           ...               ...
# 3215              True          True              True
# 3216              True          True              True
# 3251              True          True              True
# 3252              True          True              True
# 3274              True          True              True
# 3275              True          True              True
# 3310              True          True              True
# 3311              True          True              True
# 3348              True          True              True
# 3349              True          True              True
# 3385              True          True              True
# 3386              True          True              True
# 3409              True          True              True
# 3410              True          True              True
# 3435              True          True              True
# 3436              True          True              True
# 3459              True          True              True
# 3460              True          True              True
# 3484              True          True              True
# 3485              True          True              True
# 3520              True          True              True
# 3521              True          True              True
# 3544              True          True              True
# 3545              True          True              True
# 3570              True          True              True
# 3571              True          True              True
# 3598              True          True              True
# 3599              True          True              True
# 3638              True          True              True
# 3639              True          True              True
#
# [264 rows x 14 columns]

# %%
df_rest.to_csv(os.path.join(settings_cobre.ciftify_work_dir, 'ciftify_runs_complete_{}.csv'.format(today)))

# %%
subs_to_delete_ciftify_anat = df_rest.loc[df_rest.loc[:, 'ciftify_anat_done']==False, 'subject']
for sub in subs_to_delete_ciftify_anat:
    print('rm -r {}/sub-{}'.format(settings_cobre.ciftify_work_dir, sub))

# %%
print_ciftify_fmri_deleting_code(df_rest, settings_cobre)

# %%
arguments_cnp  = docopt(run_script.__doc__, ['/scratch/edickie/saba_PINT/bids_in/ds000030/ds000030_R1.0.5/', '/scratch/edickie/saba_PINT/ciftify_fmriprep/ds000030_R1.0.5/out/', 'participant', '--task=rest'])

# %%
settings_cnp = run_script.Settings(arguments_cnp)
df_cnp = build_dataframe_of_completed_runs(settings_cnp)
df_rest_cnp = df_cnp.loc[df_cnp.loc[:, 'task']=="rest", :]
# Out:
# cmd: bids-validator /scratch/edickie/saba_PINT/bids_in/ds000030/ds000030_R1.0.5/
#  Failed with returncode 127
# /bin/sh: 1: bids-validator: not found
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [session] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-ff41ed3c874a> in <module>()
#       1 settings_cnp = run_script.Settings(arguments_cnp)
# ----> 2 df_cnp = build_dataframe_of_completed_runs(settings_cnp)
#       3 df_rest_cnp = df_cnp.loc[df_cnp.loc[:, 'task']=="rest", :]
#
# <ipython-input-3-f064ede25f92> in build_dataframe_of_completed_runs(settings)
#      11             bold_input_list = settings.bids_layout.get(subject = df.loc[idx, 'subject'],
#      12                                                        type="bold",
# ---> 13                                                        session = df.loc[idx, 'session'],
#      14                                                        task = df.loc[idx, 'task'],
#      15                                                        extensions=["nii.gz", "nii"])
#
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     990
#     991                 # This is an elided recursive call to iloc/loc/etc'
# --> 992                 return getattr(section, self.name)[new_key]
#     993
#     994         raise IndexingError('not applicable')
#
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1440                 raise
#    1441             except:
# -> 1442                 error()
#    1443
#    1444         return True
#
# /projects/edickie/code/miniconda3/envs/ciftify_prereqs/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#    1431             try:
#
# KeyError: 'the label [session] is not in the [index]'

# %%
settings_cnp.bids_layout.get_sessions()
# Out:
# []

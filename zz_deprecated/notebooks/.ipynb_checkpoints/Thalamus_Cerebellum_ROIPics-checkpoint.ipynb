# %%
import nilearn.plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
VI_cerebellum_L = '/projects/dmiranda/subcortical/volume_labels/L_cerebellum_1.nii.gz'
VI_cerebellum_R = '/projects/dmiranda/subcortical/volume_labels/R_cerebellum_1.nii.gz'
SM_cerebellum_L = '/projects/dmiranda/subcortical/volume_labels/L_cerebellum_2.nii.gz'
SM_cerebellum_R = '/projects/dmiranda/subcortical/volume_labels/R_cerebellum_2.nii.gz'
DA_cerebellum_L = '/projects/dmiranda/subcortical/volume_labels/L_cerebellum_3.nii.gz'
DA_cerebellum_R = '/projects/dmiranda/subcortical/volume_labels/R_cerebellum_3.nii.gz'
VA_cerebellum_L = '/projects/dmiranda/subcortical/volume_labels/L_cerebellum_4.nii.gz'
VA_cerebellum_R = '/projects/dmiranda/subcortical/volume_labels/R_cerebellum_4.nii.gz'
FP_cerebellum_L = '/projects/dmiranda/subcortical/volume_labels/L_cerebellum_6.nii.gz'
FP_cerebellum_R = '/projects/dmiranda/subcortical/volume_labels/R_cerebellum_6.nii.gz'
DM_cerebellum_L = '/projects/dmiranda/subcortical/volume_labels/L_cerebellum_7.nii.gz'
DM_cerebellum_R = '/projects/dmiranda/subcortical/volume_labels/R_cerebellum_7.nii.gz'

VI_thalamus_L = '/projects/dmiranda/subcortical/volume_labels/L_thalamus_1.nii.gz'
VI_thalamus_R = '/projects/dmiranda/subcortical/volume_labels/R_thalamus_1.nii.gz'
SM_thalamus_L = '/projects/dmiranda/subcortical/volume_labels/L_thalamus_2.nii.gz'
SM_thalamus_R = '/projects/dmiranda/subcortical/volume_labels/R_thalamus_2.nii.gz'
DA_thalamus_L = '/projects/dmiranda/subcortical/volume_labels/L_thalamus_3.nii.gz'
DA_thalamus_R = '/projects/dmiranda/subcortical/volume_labels/R_thalamus_3.nii.gz'
VA_thalamus_L = '/projects/dmiranda/subcortical/volume_labels/L_thalamus_4.nii.gz'
VA_thalamus_R = '/projects/dmiranda/subcortical/volume_labels/R_thalamus_4.nii.gz'
FP_thalamus_L = '/projects/dmiranda/subcortical/volume_labels/L_thalamus_6.nii.gz'
FP_thalamus_R = '/projects/dmiranda/subcortical/volume_labels/R_thalamus_6.nii.gz'
DM_thalamus_L = '/projects/dmiranda/subcortical/volume_labels/L_thalamus_7.nii.gz'
DM_thalamus_R = '/projects/dmiranda/subcortical/volume_labels/R_thalamus_7.nii.gz'

full_cer_R = '/projects/dmiranda/subcortical/separate/rsn_CEREBELLUM_RIGHT.nii.gz'
full_cer_L = '/projects/dmiranda/subcortical/separate/rsn_CEREBELLUM_LEFT.nii.gz'

full_thal_L = '/projects/dmiranda/subcortical/separate/rsn_THALAMUS_LEFT.nii.gz'
full_thal_R = '/projects/dmiranda/subcortical/separate/rsn_THALAMUS_RIGHT.nii.gz' 

full_thal ='/projects/dmiranda/subcortical/full_labels/thalamus_choi.nii.gz'

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_cer_L, filled= True, colors ='grey')
display.add_contours(full_cer_R, filled= True, colors ='grey')
display.add_contours(VI_cerebellum_L, filled = True, colors = '#781286')
display.add_contours(VI_cerebellum_R, filled = True, colors = '#781286')
display.title('VI_cerebellum')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_cer_L, filled= True, colors ='grey')
display.add_contours(full_cer_R, filled= True, colors ='grey')
display.add_contours(SM_cerebellum_L, filled = True, colors = '#4682b4')
display.add_contours(SM_cerebellum_R, filled = True, colors = '#4682b4')
display.title('SM_cerebellum')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_cer_L, filled= True, colors ='grey')
display.add_contours(full_cer_R, filled= True, colors ='grey')
display.add_contours(DM_cerebellum_L, filled = True, colors = '#cd3e4e')
display.add_contours(DM_cerebellum_R, filled = True, colors = '#cd3e4e')
display.title('DM_cerebellum')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_cer_L, filled= True, colors ='grey')
display.add_contours(full_cer_R, filled= True, colors ='grey')
display.add_contours(VA_cerebellum_L, filled = True, colors = '#c43afa')
display.add_contours(VA_cerebellum_R, filled = True, colors = '#c43afa')
#display.title('VA_cerebellum')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_cer_L, filled= True, colors ='grey')
display.add_contours(full_cer_R, filled= True, colors ='grey')
display.add_contours(FP_cerebellum_L, filled = True, colors = '#e69422')
display.add_contours(FP_cerebellum_R, filled = True, colors = '#e69422')
display.title('FP_cerebellum')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_cer_L, filled= True, colors ='grey')
display.add_contours(full_cer_R, filled= True, colors ='grey')
display.add_contours(SM_cerebellum_L, filled = True, colors = '#4682b4')
display.add_contours(SM_cerebellum_R, filled = True, colors = '#4682b4')
display.title('DA_cerebellum')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_thal_L, filled= True, colors ='grey')
display.add_contours(full_thal_R, filled= True, colors ='grey')
display.add_contours(VI_thalamus_L, filled = True, colors = '#781286')
display.add_contours(VI_thalamus_R, filled = True, colors = '#781286')
display.title('VI_thalamus')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_thal_L, filled= True, colors ='grey')
display.add_contours(full_thal_R, filled= True, colors ='grey')
display.add_contours(SM_thalamus_L, filled = True, colors = '#4682b4')
display.add_contours(SM_thalamus_R, filled = True, colors = '#4682b4')
display.title('SM_thalamus')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_thal_L, filled= True, colors ='grey')
display.add_contours(full_thal_R, filled= True, colors ='grey')
display.add_contours(DM_thalamus_L, filled = True, colors = '#cd3e4e')
display.add_contours(DM_thalamus_R, filled = True, colors = '#cd3e4e')
display.title('DM_thalamus')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_thal_L, filled= True, colors ='grey')
display.add_contours(full_thal_R, filled= True, colors ='grey')
display.add_contours(VA_thalamus_L, filled = True, colors = '#c43afa')
display.add_contours(VA_thalamus_R, filled = True, colors = '#c43afa')
display.title('VA_thalamus')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_thal_L, filled= True, colors ='grey')
display.add_contours(full_thal_R, filled= True, colors ='grey')
display.add_contours(FP_thalamus_L, filled = True, colors = '#e69422')
display.add_contours(FP_thalamus_R, filled = True, colors = '#e69422')
# display.title('FP_thalamus')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_thal_L, filled= True, colors ='grey')
display.add_contours(full_thal_R, filled= True, colors ='grey')
display.add_contours(DA_thalamus_L, colors = '#00760e')
display.add_contours(DA_thalamus_R, colors = '#00760e')
#display.title('DA_thalamus')

# %%
display = nilearn.plotting.plot_glass_brain(None,display_mode='r')
#display.add_contours(full_thal_L, filled= True, colors ='grey')
display.add_contours(full_thal_R, filled= True, colors ='grey')
# display.add_contours(DA_thalamus_L, colors = 'green')
display.add_contours(DA_thalamus_R, colors = 'green')
display.title('DA_thalamus')

# %%
display = nilearn.plotting.plot_glass_brain(None)
display.add_contours(full_thal, filled= True, colors ='grey')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-30b787186795> in <module>()
#       1 display = nilearn.plotting.plot_glass_brain(None)
# ----> 2 display.add_contours(full_thal, filled= True, colors ='grey')
#
# /opt/quarantine/python/3.6_ciftify_01/build/lib/python3.6/site-packages/nilearn/plotting/displays.py in add_contours(self, img, threshold, filled, **kwargs)
#     624             different.
#     625         """
# --> 626         self._map_show(img, type='contour', **kwargs)
#     627         if filled:
#     628             if 'levels' in kwargs:
#
# /opt/quarantine/python/3.6_ciftify_01/build/lib/python3.6/site-packages/nilearn/plotting/displays.py in _map_show(self, img, type, resampling_interpolation, threshold, **kwargs)
#     653         affine = _utils.compat.get_affine(img)
# ...
